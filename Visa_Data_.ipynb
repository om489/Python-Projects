# %% [markdown]
# # Visa Data Analysis

# %% [markdown]
# **import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Read Data**

# %%
visa_df=pd.read_csv('Visadataset (2).csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Head**

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# **Tail**

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# **info**

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# **checking null value**

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# **Identifying columns**

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **Checking shape**

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# **Seperating Categorical and Numerical columns**

# %%
cat=visa_df.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Take**

# %%
l=[1,2,3,4,5,6]
visa_df.take(l,axis=1)
# Out:
#       continent education_of_employee has_job_experience  \
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %% [markdown]
# # Categorical Column Analysis

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **Case Distribution by Continent**

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.figure(figsize=(10,5))
plt.bar(keys,values)
plt.xlabel('Class')
plt.ylabel('Class Frequency') #x-axis
plt.title('Continent Barchart') #y-axis
plt.savefig('continent_bar_chart.png')
plt.show() #always at last

# %%
keys=visa_df['education_of_employee'].value_counts().keys()
values=visa_df['education_of_employee'].value_counts().values
plt.figure(figsize=(10,5))
plt.bar(keys,values)
plt.xlabel('Class')
plt.ylabel('Class Frequency') #x-axis
plt.title('education_of_employee') #y-axis
plt.show() #always at last

# %%
keys=visa_df['has_job_experience'].value_counts().keys()
values=visa_df['has_job_experience'].value_counts().values
plt.figure(figsize=(10,5))
plt.bar(keys,values)
plt.xlabel('Class')
plt.ylabel('Class Frequency') #x-axis
plt.title('has_job_experience') #y-axis
plt.show() #always at last

# %%
keys=visa_df['requires_job_training'].value_counts().keys()
values=visa_df['requires_job_training'].value_counts().values
plt.figure(figsize=(10,5))
plt.bar(keys,values)
plt.xlabel('Class')
plt.ylabel('Class Frequency') #x-axis
plt.title('requires_job_training') #y-axis
plt.show() #always at last

# %%
keys=visa_df['region_of_employment'].value_counts().keys()
values=visa_df['region_of_employment'].value_counts().values
plt.figure(figsize=(10,5))
plt.bar(keys,values)
plt.xlabel('Class')
plt.ylabel('Class Frequency') #x-axis
plt.title('rregion_of_employment') #y-axis
plt.show() #always at last

# %%
keys=visa_df['case_status'].value_counts().keys()
values=visa_df['case_status'].value_counts().values
plt.figure(figsize=(10,5))
plt.bar(keys,values)
plt.xlabel('Class')
plt.ylabel('Class Frequency') #x-axis
plt.title('case_status') #y-axis
plt.show() #always at last

# %%
plt.figure(figsize=(17, 6))
for i in range(1, 9):
    keys = visa_df[cat[i]].value_counts().keys()
    plt.subplot(3, 3, i)
    
    # Use the column name directly as the x parameter
    sns.countplot(data=visa_df, x=cat[i], order=keys)  # Changed here

plt.tight_layout()  # Adjust layout
plt.show()

# %%
keys = visa_df['continent'].value_counts().keys()  # categories like 'Asia', 'Europe'
values = visa_df['continent'].value_counts().values  # corresponding counts of each category
plt.pie(values, 
        labels=keys, 
        autopct='%0.2f%%')  # autopct to display percentage on the chart
plt.show()

# %%
keys = visa_df['education_of_employee'].value_counts().keys()  # categories like 'Asia', 'Europe'
values = visa_df['education_of_employee'].value_counts().values  # corresponding counts of each category
plt.pie(values, 
        labels=keys, 
        autopct='%0.2f%%')  # autopct to display percentage on the chart
plt.show()

# %%
keys = visa_df['has_job_experience'].value_counts().keys()  # categories like 'Asia', 'Europe'
values = visa_df['has_job_experience'].value_counts().values  # corresponding counts of each category
plt.pie(values, 
        labels=keys, 
        autopct='%0.2f%%')  # autopct to display percentage on the chart
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='continent', data=visa_df, palette='coolwarm')
plt.xlabel('Continent')
plt.ylabel('Number of Cases')
plt.title('Distribution of Cases by Continent')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='education_of_employee', data=visa_df, palette='Set2')
plt.xlabel('Education Level')
plt.ylabel('Number of Employees')
plt.title('Education Level Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='has_job_experience', hue='requires_job_training', data=visa_df, palette='Set3')
plt.xlabel('Has Job Experience')
plt.ylabel('Number of Employees')
plt.title('Job Experience vs. Job Training Requirement')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x='no_of_employees', y='prevailing_wage', data=visa_df, hue='continent', palette='cool')
plt.xlabel('Number of Employees')
plt.ylabel('Prevailing Wage')
plt.title('Company Size vs. Prevailing Wage')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x='yr_of_estab', y='prevailing_wage', data=visa_df, marker='o', color='green')
plt.xlabel('Year of Establishment')
plt.ylabel('Prevailing Wage')
plt.title('Year of Establishment vs. Prevailing Wage')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='full_time_position', y='prevailing_wage', data=visa_df, palette='Blues')
plt.xlabel('Full-Time Position')
plt.ylabel('Prevailing Wage')
plt.title('Full-Time Position vs. Prevailing Wage')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='case_status', data=visa_df, palette='Pastel1')
plt.xlabel('Case Status')
plt.ylabel('Number of Cases')
plt.title('Distribution of Case Status')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='education_of_employee', hue='case_status', data=visa_df, palette='Set1')
plt.xlabel('Education Level')
plt.ylabel('Number of Cases')
plt.title('Education Level vs. Case Status')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='region_of_employment', y='prevailing_wage', data=visa_df, palette='Set3')
plt.xlabel('Region of Employment')
plt.ylabel('Prevailing Wage')
plt.title('Region of Employment vs. Prevailing Wage')
plt.xticks(rotation=45)  # Rotate x labels if necessary
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='requires_job_training', y='no_of_employees', data=visa_df, palette='Set2')
plt.xlabel('Requires Job Training')
plt.ylabel('Number of Employees')
plt.title('Job Training Requirement vs. Company Size')
plt.show()

# %% [markdown]
# # Numerical Column Analysis

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **Non outliers data**

# %%
wage_data=visa_df['prevailing_wage']
q1=round(np.quantile(wage_data,0.25),2)
q3=round(np.quantile(wage_data,0.75),2)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=visa_df['prevailing_wage']>lb
con2=visa_df['prevailing_wage']<ub
con3=con1&con2
count=len(visa_df[con3])
non_outliers_data=visa_df[con3]
non_outliers_data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
sns.histplot(non_outliers_data['prevailing_wage'],bins=20,kde=True)
plt.show()

# %%
sns.boxplot(non_outliers_data['prevailing_wage'],orient='h')
plt.show()

# %%
plt.figure(figsize=(12, 10))  # Adjust figure size as necessary

plt.subplot(2, 2, 1)
plt.hist(visa_df['prevailing_wage'], bins=10, color='blue', edgecolor='black')
plt.title('Wage Histogram')
plt.xlabel('Prevailing Wage')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.boxplot(visa_df['prevailing_wage'], vert=False)
plt.title('Wage Boxplot')
plt.xlabel('Prevailing Wage')

plt.subplot(2, 2, 3)
plt.hist(non_outliers_data['prevailing_wage'], bins=10, color='green', edgecolor='black')
plt.title('Wage Histogram without Outliers')
plt.xlabel('Prevailing Wage')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.boxplot(non_outliers_data['prevailing_wage'], vert=False)
plt.title('Wage Boxplot without Outliers')
plt.xlabel('Prevailing Wage')

plt.suptitle("Wage Plots", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to fit the suptitle
plt.show()

# %% [markdown]
# # Handling Outliers

# %%
# Extract prevailing_wage column
wage_data = visa_df['prevailing_wage']

# Calculate the 1st and 3rd quartile
q1 = round(np.quantile(wage_data, 0.25), 2)
q3 = round(np.quantile(wage_data, 0.75), 2)

# Compute the IQR
IQR = q3 - q1

# Set the lower bound and upper bound
lb = q1 - 1.5 * IQR
ub = q3 + 1.5 * IQR

# Create conditions to identify non-outliers
con1 = visa_df['prevailing_wage'] > lb
con2 = visa_df['prevailing_wage'] < ub
con3 = con1 & con2

# Filter out the non-outliers
non_outliers_data = visa_df[con3]

# Get the count of non-outliers
count = len(non_outliers_data)

# Print the result
print(f"Number of non-outliers: {count}")
print(non_outliers_data.head())  # Optional: view the filtered data
# Out:
# Number of non-outliers: 25053
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# ...

# %% [markdown]
# **Fill with median**

# %%
# Extract prevailing_wage column
wage_data = visa_df['prevailing_wage']

# Calculate the 1st and 3rd quartile
q1 = round(np.quantile(wage_data, 0.25), 2)
q3 = round(np.quantile(wage_data, 0.75), 2)

# Compute the IQR and the lower and upper bounds
IQR = q3 - q1
lb = q1 - 1.5 * IQR
ub = q3 + 1.5 * IQR

# Calculate the median
median = wage_data.median()

# Replace outliers with the median using list comprehension
new_data = [median if (i < lb or i > ub) else i for i in wage_data]

# Add the new data as a column to the DataFrame
visa_df['pwage'] = new_data

# Check the results
print(visa_df[['prevailing_wage', 'pwage']].head())
# Out:
#    prevailing_wage        pwage
# 0         592.2029     592.2029
# 1       83425.6500   83425.6500
# 2      122996.8600  122996.8600
# 3       83434.0300   83434.0300
# 4      149907.3900  149907.3900

# %%
# Plot the histogram for 'pwage'
plt.hist(visa_df['pwage'], bins=30, color='skyblue', edgecolor='black', alpha=0.7)

# Add a title and labels for clarity
plt.title('Distribution of Adjusted Prevailing Wage (pwage)', fontsize=14)
plt.xlabel('Prevailing Wage (pwage)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot with tighter layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Extract prevailing_wage column
wage_data = visa_df['prevailing_wage']

# Calculate the 1st and 3rd quartile
q1 = round(np.quantile(wage_data, 0.25), 2)
q3 = round(np.quantile(wage_data, 0.75), 2)

# Compute the IQR and the lower and upper bounds
IQR = q3 - q1
lb = q1 - 1.5 * IQR
ub = q3 + 1.5 * IQR

# Calculate the median
median = wage_data.median()

# Use np.where() to replace outliers with the median
visa_df['p_wage_1'] = np.where((visa_df['prevailing_wage'] < lb) | (visa_df['prevailing_wage'] > ub),
                               median, 
                               visa_df['prevailing_wage'])

# Check the results
print(visa_df[['prevailing_wage', 'p_wage_1']].head())
# Out:
#    prevailing_wage     p_wage_1
# 0         592.2029     592.2029
# 1       83425.6500   83425.6500
# 2      122996.8600  122996.8600
# 3       83434.0300   83434.0300
# 4      149907.3900  149907.3900

# %%
# Create a horizontal box plot for the 'p_wage_1' column
plt.boxplot(visa_df['p_wage_1'], vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightblue'))

# Add title and labels for better clarity
plt.title('Box Plot of Adjusted Prevailing Wage', fontsize=14)
plt.xlabel('Prevailing Wage (p_wage_1)', fontsize=12)

# Display the box plot
plt.show()
